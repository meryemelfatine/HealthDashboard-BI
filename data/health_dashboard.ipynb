# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

# Affichage plus joli
sns.set(style="whitegrid")
plt.rcParams['figure.figsize'] = (10,5)
# Out:
# C:\Users\user\AppData\Roaming\Python\Python312\site-packages\seaborn\_statistics.py:32: UserWarning: A NumPy version >=1.23.5 and <2.3.0 is required for this version of SciPy (detected version 2.3.2)
#   from scipy.stats import gaussian_kde

# %%
df = pd.read_csv("health_data.csv")
df.head()
# Out:
#    country  year  life_expectancy  health_expenditure_per_capita  \
# 0   France  2018             82.5                           4500
# 1   France  2019             82.6                           4600
# 2   France  2020             82.4                           4700
# 3  Morocco  2018             76.5                           1500
# 4  Morocco  2019             76.7                           1600
#
#    infant_mortality_rate
# 0                    3.1
# 1                    3.0
# 2                    3.2
# 3                   18.0
# 4                   17.5

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.lineplot(data=df, x='year', y='life_expectancy', hue='country', marker='o')
plt.title("Évolution de l'espérance de vie par pays")
plt.ylabel("Espérance de vie (années)")
plt.show()

# %%
# !pip install ipywidgets
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
#   Using cached ipywidgets-8.1.7-py3-none-any.whl.metadata (2.4 kB)
# ...
#   Using cached widgetsnbextension-4.0.14-py3-none-any.whl.metadata (1.6 kB)
# ...
#   Using cached jupyterlab_widgets-3.0.15-py3-none-any.whl.metadata (20 kB)
# ...
# Using cached ipywidgets-8.1.7-py3-none-any.whl (139 kB)
# Using cached jupyterlab_widgets-3.0.15-py3-none-any.whl (216 kB)
# Using cached widgetsnbextension-4.0.14-py3-none-any.whl (2.2 MB)
# ...
#
#    ---------------------------------------- 0/3 [widgetsnbextension]
#    ---------------------------------------- 0/3 [widgetsnbextension]
#    ------------- -------------------------- 1/3 [jupyterlab_widgets]
#    ------------- -------------------------- 1/3 [jupyterlab_widgets]
#    ------------- -------------------------- 1/3 [jupyterlab_widgets]
# ...

# %%
import ipywidgets as widgets
from IPython.display import display
import matplotlib.pyplot as plt

# Préparer les données par pays une seule fois
country_data = {c: df[df['country'] == c] for c in df['country'].unique()}

# Création du menu déroulant
country_dropdown = widgets.Dropdown(
    options=list(country_data.keys()),
    description='Pays :',
    value=list(country_data.keys())[0]
)

# Fonction optimisée
def plot_filtered(country):
    data = country_data[country]
    plt.clf()  # Effacer l'ancien graphique
    plt.plot(data['year'], data['life_expectancy'], marker='o')
    plt.title(f"Évolution de l'espérance de vie - {country}")
    plt.ylabel("Espérance de vie (années)")
    plt.xlabel("Année")
    plt.grid(True)
    plt.show()

# Lier le menu
widgets.interact(plot_filtered, country=country_dropdown)
